# %%
# !ls public
# Out:
# TeamLevelPoints.json logo192.png          manifest.json
# favicon.ico          logo512.png          mmb2021o-kp.wpt
# index.html           maindata.json        robots.txt

# %%
import json
data = json.load(open('public/maindata.json'))

# %%
data.keys()
# Out:
# dict_keys(['Raids', 'Distances', 'Teams', 'Invitations', 'Users', 'TeamUsers', 'Levels', 'TeamLevelDismiss'])

# %%
data['Users']
# Out:
# [{'user_id': '51',
#   'user_name': 'Сучков Александр',
#   'user_birthyear': '1988',
#   'user_city': 'Одинцово',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.45157',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3741',
#   'user_name': 'Пользователь скрыл данные',
#   'user_birthyear': '1977',
#   'user_city': '',
#   'user_minraidid': '23',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '5.11240',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2947',
#   'user_name': 'Зезекало Александр',
#   'user_birthyear': '1975',
#   'user_city': None,
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.55186',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '690',
#   'user_name': 'Сафронов Павел',
#   'user_birthyear': '1986',
#   'user_city': '',
#   'user_minraidid': '19',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '25',
#   'user_r6': '1.34829',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11439',
#   'user_name': 'Кулемзин Евгений',
#   'user_birthyear': '1988',
#   'user_city': 'Протвино, ТК Перово',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.16819',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8697',
#   'user_name': 'Мезрин Алексей',
#   'user_birthyear': '1985',
#   'user_city': 'Трудовая, МО',
#   'user_minraidid': '25',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.99598',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1984',
#   'user_name': 'Посадский Алексей',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '10',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.53673',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13623',
#   'user_name': 'Евсеев Вадим',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.27147',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13975',
#   'user_name': 'Шмарина Таня',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.97580',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14736',
#   'user_name': 'Масленников Андрей',
#   'user_birthyear': '1978',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.24818',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3172',
#   'user_name': 'Власенко Олег',
#   'user_birthyear': '1973',
#   'user_city': 'Москва',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.90712',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8988',
#   'user_name': 'Ворноскова Ольга',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '25',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.49260',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '9993',
#   'user_name': 'Родионов Андрей',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '35',
#   'user_r6': '1.61868',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10223',
#   'user_name': 'Павел Честный',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.16347',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14826',
#   'user_name': 'Антипов',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10230',
#   'user_name': 'Александр Эйферт',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '27',
#   'user_r6': '0.86214',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11998',
#   'user_name': 'Докукин Дмитрий',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.36974',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11721',
#   'user_name': 'Аюгин Александр',
#   'user_birthyear': '1979',
#   'user_city': 'Московский',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.62243',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12918',
#   'user_name': 'Савельев Михаил',
#   'user_birthyear': '1977',
#   'user_city': 'Москва',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.12502',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2399',
#   'user_name': 'Пользователь скрыл данные',
#   'user_birthyear': '1987',
#   'user_city': '',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.61503',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3251',
#   'user_name': 'Тихонов Алексей',
#   'user_birthyear': '1984',
#   'user_city': 'Шевлягино',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.67038',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10699',
#   'user_name': 'Кузьмин Андрей',
#   'user_birthyear': '1986',
#   'user_city': 'Шевлягино',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.38886',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '350',
#   'user_name': 'Сталь Александр',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.23422',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '55',
#   'user_name': 'Эльман Игорь',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '8',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.33700',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14188',
#   'user_name': 'Попов Андрей',
#   'user_birthyear': '1989',
#   'user_city': 'Лыткарино',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.99348',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2394',
#   'user_name': 'Львов Сергей',
#   'user_birthyear': '1972',
#   'user_city': 'Москва',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.19711',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13102',
#   'user_name': 'Пользователь скрыл данные',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.19461',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13976',
#   'user_name': 'Аникина Анна',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.89894',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14127',
#   'user_name': 'Фархутдинов Эльдар Рафаелович',
#   'user_birthyear': '1981',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '323',
#   'user_name': 'Прудлик Сергей',
#   'user_birthyear': '1984',
#   'user_city': 'Долгопрудный',
#   'user_minraidid': '19',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.70047',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11436',
#   'user_name': 'Карлов Карл',
#   'user_birthyear': '1981',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.42955',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9860',
#   'user_name': 'Иванов Андрей',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.10349',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1725',
#   'user_name': 'Бакиров Роман',
#   'user_birthyear': '1991',
#   'user_city': 'Уфа-Москва',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.49105',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1110',
#   'user_name': 'Климов Илья',
#   'user_birthyear': '1985',
#   'user_city': '',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '21',
#   'user_r6': '5.09183',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11641',
#   'user_name': 'Болдов Роман',
#   'user_birthyear': '1984',
#   'user_city': 'Долгопрудный',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.61704',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8278',
#   'user_name': 'Конов Алексей',
#   'user_birthyear': '1984',
#   'user_city': 'Волгоград',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.68017',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2728',
#   'user_name': 'Рудяев Василий',
#   'user_birthyear': '1981',
#   'user_city': 'ТК Вестра, Масквабад',
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '22',
#   'user_r6': '2.84073',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11217',
#   'user_name': 'Левенчук Николай',
#   'user_birthyear': '1982',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.10200',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10445',
#   'user_name': 'Андрей Зозуля',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '27',
#   'user_r6': '1.70366',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14214',
#   'user_name': 'Андрей Мызников',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.70448',
#   'user_noinvitation': None,
#   'user_sex': '0'},
#  {'user_id': '13326',
#   'user_name': 'Кирилл Козлов',
#   'user_birthyear': '1999',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.46535',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2502',
#   'user_name': 'Андрей Клем',
#   'user_birthyear': '1989',
#   'user_city': 'Подольск',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '22',
#   'user_r6': '1.40912',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14447',
#   'user_name': 'Викторенко Никита',
#   'user_birthyear': '2000',
#   'user_city': 'Королёв',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25320',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14453',
#   'user_name': 'Морозов Александр',
#   'user_birthyear': '2000',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25320',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14449',
#   'user_name': 'Переведенцев Михаил',
#   'user_birthyear': '2000',
#   'user_city': 'Мытищи',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25320',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14669',
#   'user_name': 'Мороз Артём',
#   'user_birthyear': '2002',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25320',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14099',
#   'user_name': 'Денис Давыдов',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1112',
#   'user_name': 'Иванов Евгений',
#   'user_birthyear': '1982',
#   'user_city': '',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.52414',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10187',
#   'user_name': 'Бобров Олег',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.78513',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '4057',
#   'user_name': 'Вишняков Александр',
#   'user_birthyear': '1973',
#   'user_city': 'Дублин',
#   'user_minraidid': '6',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '23',
#   'user_r6': '1.69336',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2899',
#   'user_name': 'Козлов Андрей',
#   'user_birthyear': '1987',
#   'user_city': 'Ленинград-Обнинск-Москва',
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.89970',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12149',
#   'user_name': 'Гунин Сергей',
#   'user_birthyear': '1978',
#   'user_city': 'Санкт-Петербург',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.99214',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14666',
#   'user_name': 'Золина Татьяна',
#   'user_birthyear': '1987',
#   'user_city': 'Санкт-Петербург',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '3573',
#   'user_name': 'Седов Георгий',
#   'user_birthyear': '1995',
#   'user_city': 'Москва',
#   'user_minraidid': '23',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.57420',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14744',
#   'user_name': 'Соколова Марина',
#   'user_birthyear': '1998',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.35652',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14467',
#   'user_name': 'Миннигалиева Лилия',
#   'user_birthyear': '2002',
#   'user_city': 'Балабаново',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.35652',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13852',
#   'user_name': 'Власов Олег',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.74844',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13860',
#   'user_name': 'Воронин Илья',
#   'user_birthyear': '1990',
#   'user_city': 'Мытищи',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.43390',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13854',
#   'user_name': 'Тухфатуллин Тимур',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9968',
#   'user_name': 'Сумин Дмитрий',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.54344',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12099',
#   'user_name': 'Чувашева Елена',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.17822',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14796',
#   'user_name': 'Никишин Роман',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.22782',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14805',
#   'user_name': 'Рыбкина Вера',
#   'user_birthyear': '2003',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.22782',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '1526',
#   'user_name': 'Коваль Дмитрий',
#   'user_birthyear': '1982',
#   'user_city': 'Москва',
#   'user_minraidid': '7',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.12846',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '153',
#   'user_name': 'Моисеева Анна',
#   'user_birthyear': '1976',
#   'user_city': 'Москва',
#   'user_minraidid': '11',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.26343',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '12748',
#   'user_name': 'Дубовой Григорий',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.90450',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13397',
#   'user_name': 'Кайбышев Денис',
#   'user_birthyear': '1986',
#   'user_city': 'Люберцы',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.72330',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1402',
#   'user_name': 'Сафиулин Тимур',
#   'user_birthyear': '1981',
#   'user_city': '',
#   'user_minraidid': '17',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '24',
#   'user_r6': '1.86502',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14415',
#   'user_name': 'Поскотин Анатолий',
#   'user_birthyear': '1984',
#   'user_city': 'Красногорск',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.26274',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '558',
#   'user_name': 'Ташпулатов Тимур',
#   'user_birthyear': '1987',
#   'user_city': 'Москва-Владивосток',
#   'user_minraidid': '8',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '22',
#   'user_r6': '1.13583',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3927',
#   'user_name': 'Епанечников Сергей',
#   'user_birthyear': '1987',
#   'user_city': 'Тверь',
#   'user_minraidid': '23',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '30',
#   'user_r6': '1.72161',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10673',
#   'user_name': 'Туркин Михаил',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.69356',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11546',
#   'user_name': 'Лупиносова Алеся',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.90828',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13887',
#   'user_name': 'Ефремов Андрей',
#   'user_birthyear': '1983',
#   'user_city': 'Краснотурьинск',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.31493',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '249',
#   'user_name': 'Муратов Андрей',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '12',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '4.02308',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11763',
#   'user_name': 'Салов Александр',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.29834',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13453',
#   'user_name': 'Светлана Горшкова',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.80770',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14563',
#   'user_name': 'Насонова Екатерина',
#   'user_birthyear': '1998',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.28153',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '12123',
#   'user_name': 'Белоцерковский Денис',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.42381',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10157',
#   'user_name': 'Рыбалкин Дмитрий',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.48574',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9786',
#   'user_name': 'Бабкин Тимофей',
#   'user_birthyear': '1988',
#   'user_city': 'Железнодорожный',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.64848',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '4374',
#   'user_name': 'Лоскутников Денис',
#   'user_birthyear': '1982',
#   'user_city': 'москва',
#   'user_minraidid': '23',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.03084',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2551',
#   'user_name': 'Боричев Константин',
#   'user_birthyear': '1978',
#   'user_city': 'Москва',
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.96742',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14808',
#   'user_name': 'Боричев Артем',
#   'user_birthyear': '2006',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.28310',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '836',
#   'user_name': 'Четкин Андрей',
#   'user_birthyear': '1979',
#   'user_city': 'Воронеж',
#   'user_minraidid': '10',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '21',
#   'user_r6': '3.23094',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12909',
#   'user_name': 'Галатонова Юлия',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.41698',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '12624',
#   'user_name': 'Царевский Василий',
#   'user_birthyear': '1991',
#   'user_city': 'Москва',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.83618',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11288',
#   'user_name': 'Вакулюк Мария',
#   'user_birthyear': '1997',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '32',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.77386',
#   'user_noinvitation': '1',
#   'user_sex': '1'},
#  {'user_id': '593',
#   'user_name': 'Никонов Михаил',
#   'user_birthyear': '1979',
#   'user_city': 'Москва',
#   'user_minraidid': '9',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.86130',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11395',
#   'user_name': 'Браверман Елена',
#   'user_birthyear': '1986',
#   'user_city': 'Одинцово',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.15559',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13801',
#   'user_name': 'Гордеева Юлия',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.32134',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '196',
#   'user_name': 'Лапицкий Дмитрий',
#   'user_birthyear': '1985',
#   'user_city': '',
#   'user_minraidid': '9',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '24',
#   'user_r6': '0.82364',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3414',
#   'user_name': 'Данилов Владимир',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '22',
#   'user_maxraidid': '32',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '1.73269',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '8862',
#   'user_name': 'Зотов Алексей',
#   'user_birthyear': '1981',
#   'user_city': 'Москва',
#   'user_minraidid': '25',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.06332',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2927',
#   'user_name': 'Гайдай Александр',
#   'user_birthyear': '1988',
#   'user_city': '',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.04837',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13140',
#   'user_name': 'Левщанов Степан',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.33058',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14664',
#   'user_name': 'Ксения Алексеева',
#   'user_birthyear': '1993',
#   'user_city': 'Химки',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14665',
#   'user_name': 'Артем Горбачев',
#   'user_birthyear': '1994',
#   'user_city': 'Химки',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14486',
#   'user_name': 'Филиппенков Сергей',
#   'user_birthyear': '1979',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.28559',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14506',
#   'user_name': 'Терёшкин Валерий',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.63692',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11620',
#   'user_name': 'Беляков Денис',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.58229',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12967',
#   'user_name': 'Дамарад Александр',
#   'user_birthyear': '1978',
#   'user_city': 'Рождествено',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.02282',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13822',
#   'user_name': 'Горшков Тимофей',
#   'user_birthyear': '2004',
#   'user_city': 'Дедовск',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.39965',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13274',
#   'user_name': 'Захаров Дионисий',
#   'user_birthyear': '2000',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.27111',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3088',
#   'user_name': 'Шумаева Дарья',
#   'user_birthyear': '1981',
#   'user_city': 'Красногорск',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.63931',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '714',
#   'user_name': 'Андреев Алексей',
#   'user_birthyear': '1982',
#   'user_city': 'ТК Перово',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.68929',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14674',
#   'user_name': 'Толкачева Марина',
#   'user_birthyear': '1998',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.34369',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14667',
#   'user_name': 'Кулагин Александр',
#   'user_birthyear': '1997',
#   'user_city': 'Мытищи',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.34369',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '356',
#   'user_name': 'Косачев Михаил',
#   'user_birthyear': '1983',
#   'user_city': None,
#   'user_minraidid': '12',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.81591',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '298',
#   'user_name': 'Васильев Эрнольд',
#   'user_birthyear': '1974',
#   'user_city': 'Лобня',
#   'user_minraidid': '13',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.60912',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '753',
#   'user_name': 'Парыгин Евгений',
#   'user_birthyear': '1987',
#   'user_city': 'Химки',
#   'user_minraidid': '15',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '24',
#   'user_r6': '1.43979',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '968',
#   'user_name': 'Валерий Яковлев',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '20',
#   'user_r6': '0.63628',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14853',
#   'user_name': 'Некраш Анастасия',
#   'user_birthyear': '1994',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.35491',
#   'user_noinvitation': None,
#   'user_sex': '0'},
#  {'user_id': '98',
#   'user_name': 'Смелов Александр',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '17',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.13829',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '174',
#   'user_name': 'Иноземцев Антон',
#   'user_birthyear': '1982',
#   'user_city': 'Реутов',
#   'user_minraidid': '8',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '24',
#   'user_r6': '3.95887',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13010',
#   'user_name': 'Матвеев Олег',
#   'user_birthyear': '1982',
#   'user_city': 'Зеленоград',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.68124',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14319',
#   'user_name': 'Махмудов Якуб',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.23076',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10306',
#   'user_name': 'Александр Шепилов',
#   'user_birthyear': '1979',
#   'user_city': 'Москва',
#   'user_minraidid': '13',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.42933',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12342',
#   'user_name': 'Абдрахманов Денис',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.40439',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12343',
#   'user_name': 'Пысин Андрей',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.62918',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12589',
#   'user_name': 'Махалин Андрей',
#   'user_birthyear': '1989',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.07116',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8743',
#   'user_name': 'Дробиленко Андрей',
#   'user_birthyear': '1982',
#   'user_city': 'Москва',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.25832',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '120',
#   'user_name': 'Семин Михаил',
#   'user_birthyear': '1964',
#   'user_city': 'Москва',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.67315',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2623',
#   'user_name': 'Южаков Глеб',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.02155',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8311',
#   'user_name': 'Александр Хлебников',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '24',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.57685',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14656',
#   'user_name': 'Горлова Анна',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13067',
#   'user_name': 'Петрова Ольга',
#   'user_birthyear': '1994',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.76992',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '3273',
#   'user_name': 'Андриянов Роман',
#   'user_birthyear': '1975',
#   'user_city': 'Москва',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.72589',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3602',
#   'user_name': 'Курепин Александр',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '0.77247',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '895',
#   'user_name': 'Ботавин Дмитрий',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '8',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.34311',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '13431',
#   'user_name': 'Адеев Камиль',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '34',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.41599',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '14670',
#   'user_name': 'Тебин Прохор',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13712',
#   'user_name': 'Belov Konstantin',
#   'user_birthyear': '1978',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.59672',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14316',
#   'user_name': 'Суханов Дмитрий',
#   'user_birthyear': '1979',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25164',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10799',
#   'user_name': 'Гилязев Рамиль',
#   'user_birthyear': '1982',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.04620',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9106',
#   'user_name': 'Грачев Дмитрий',
#   'user_birthyear': '1986',
#   'user_city': 'Королев',
#   'user_minraidid': '25',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.72138',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2636',
#   'user_name': 'Инжеватов Павел',
#   'user_birthyear': '1986',
#   'user_city': 'Королёв',
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '21',
#   'user_r6': '0.62815',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11756',
#   'user_name': 'Дмитриев Дмитрий',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '32',
#   'user_r6': '0.21451',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14783',
#   'user_name': 'Русин Дмитрий',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.21451',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12225',
#   'user_name': 'Олег',
#   'user_birthyear': '1989',
#   'user_city': '',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.77631',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14428',
#   'user_name': 'Веселина',
#   'user_birthyear': '1994',
#   'user_city': '',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.79671',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '12096',
#   'user_name': 'Пичкалева Анна',
#   'user_birthyear': '1997',
#   'user_city': 'Москва',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.61411',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '102',
#   'user_name': 'Шведунов Александр',
#   'user_birthyear': '1981',
#   'user_city': '',
#   'user_minraidid': '8',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '25',
#   'user_r6': '2.46046',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14455',
#   'user_name': 'Наумов Геннадий',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.22262',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12296',
#   'user_name': 'Федулова Юлия',
#   'user_birthyear': '1998',
#   'user_city': 'Люберцы',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.91673',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '14448',
#   'user_name': 'Парамонов Виктор',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.22624',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8690',
#   'user_name': 'Александра Золоторевская',
#   'user_birthyear': '1997',
#   'user_city': 'москва',
#   'user_minraidid': '25',
#   'user_maxraidid': '34',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.46473',
#   'user_noinvitation': '1',
#   'user_sex': '1'},
#  {'user_id': '13505',
#   'user_name': 'Пивоваров Алексей',
#   'user_birthyear': '1985',
#   'user_city': 'Калининец',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.57300',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13907',
#   'user_name': 'Игамбердиев Кирилл',
#   'user_birthyear': '1987',
#   'user_city': 'москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '35',
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '355',
#   'user_name': 'Анастасия "Эльвер" Назарова',
#   'user_birthyear': '1991',
#   'user_city': 'Москва',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '23',
#   'user_r6': '1.89877',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '8533',
#   'user_name': 'Голованов Антон',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '24',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '25',
#   'user_r6': '1.28818',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '537',
#   'user_name': 'Баклагина Татьяна',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.05906',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '10356',
#   'user_name': 'Ярцев Герман',
#   'user_birthyear': '1973',
#   'user_city': 'Дмитров',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.29901',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14673',
#   'user_name': 'Архипов Иван',
#   'user_birthyear': '1988',
#   'user_city': 'Мытищи',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.43917',
#   'user_noinvitation': None,
#   'user_sex': '0'},
#  {'user_id': '13626',
#   'user_name': 'Тивков Василий Сергеевич',
#   'user_birthyear': '1990',
#   'user_city': 'Троицк',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.26668',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12627',
#   'user_name': 'Смолев Сергей',
#   'user_birthyear': '1992',
#   'user_city': 'Чебоксары',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.51866',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12444',
#   'user_name': 'Кузьмин Дмитрий',
#   'user_birthyear': '1982',
#   'user_city': 'Пушкино',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.56508',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14113',
#   'user_name': 'Кобец Дмитрий',
#   'user_birthyear': '1989',
#   'user_city': 'Москва,',
#   'user_minraidid': '35',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.52304',
#   'user_noinvitation': None,
#   'user_sex': '0'},
#  {'user_id': '14097',
#   'user_name': 'Романов Сергей',
#   'user_birthyear': '1991',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.52304',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11165',
#   'user_name': 'Гурьянов Дмитрий',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '28',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.18018',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12553',
#   'user_name': 'Усвайский Александр',
#   'user_birthyear': '1986',
#   'user_city': 'Щёлково',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.80487',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2403',
#   'user_name': 'Смурыгин Артём',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '24',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.39116',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2402',
#   'user_name': 'Куликовский Максим',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.46620',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2262',
#   'user_name': 'Жеребцова Светлана',
#   'user_birthyear': '1986',
#   'user_city': '',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.66462',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '2266',
#   'user_name': 'Тарабаев Вениамин',
#   'user_birthyear': '1980',
#   'user_city': '',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.66462',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1126',
#   'user_name': 'Пригоркин Сергей',
#   'user_birthyear': '1987',
#   'user_city': '',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '35',
#   'user_r6': '3.10092',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '181',
#   'user_name': 'Отачкин Алексей',
#   'user_birthyear': '1989',
#   'user_city': 'Петропавловск-Камчатский',
#   'user_minraidid': '17',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '5.54986',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '364',
#   'user_name': 'Сипин Валерий',
#   'user_birthyear': '1972',
#   'user_city': 'г.Владимир',
#   'user_minraidid': '17',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '3.33079',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '13407',
#   'user_name': 'Савельев Дмитрий',
#   'user_birthyear': '1986',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.63397',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11714',
#   'user_name': 'Женя Бурмагин',
#   'user_birthyear': '1985',
#   'user_city': 'Красноармейск',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.63395',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13853',
#   'user_name': 'Мирошников Константин',
#   'user_birthyear': '1983',
#   'user_city': 'Щёлково',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.12045',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9468',
#   'user_name': 'Криштоп Владимир',
#   'user_birthyear': '1979',
#   'user_city': 'Черноголовка',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '32',
#   'user_r6': '1.59501',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1713',
#   'user_name': 'Сергей Стороженко',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '11',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.71663',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12554',
#   'user_name': 'Ларин Сергей',
#   'user_birthyear': '1990',
#   'user_city': 'Королев',
#   'user_minraidid': '31',
#   'user_maxraidid': '34',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.82267',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '835',
#   'user_name': 'Сазонов Павел',
#   'user_birthyear': '1983',
#   'user_city': None,
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.84480',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2000',
#   'user_name': 'Соколов Алексей',
#   'user_birthyear': '1984',
#   'user_city': '',
#   'user_minraidid': '10',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.35518',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '112',
#   'user_name': 'Чирков Александр',
#   'user_birthyear': '1963',
#   'user_city': 'Троицк',
#   'user_minraidid': '11',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.50272',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11676',
#   'user_name': 'Федулов Александр',
#   'user_birthyear': '1992',
#   'user_city': 'Фрязино',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14675',
#   'user_name': 'Белова Наталья',
#   'user_birthyear': '2000',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.29721',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '1814',
#   'user_name': 'Векслер Юлия',
#   'user_birthyear': '1969',
# ...
#   'user_name': 'Соседов Кирилл',
#   'user_birthyear': '1985',
#   'user_city': '',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.27814',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14226',
#   'user_name': 'Наумов',
#   'user_birthyear': '1992',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': None,
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12462',
#   'user_name': 'Королев Вадим',
#   'user_birthyear': '1988',
#   'user_city': 'Рязань',
#   'user_minraidid': '30',
#   'user_maxraidid': '34',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.69594',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '13179',
#   'user_name': 'Головкин Александр',
#   'user_birthyear': '1984',
#   'user_city': 'Рязань',
#   'user_minraidid': '32',
#   'user_maxraidid': '34',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.48618',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '13894',
#   'user_name': 'Окунев Михаил',
#   'user_birthyear': '1980',
#   'user_city': 'Раменское',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.25054',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1056',
#   'user_name': 'Луценко Илья',
#   'user_birthyear': '1984',
#   'user_city': '',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '34',
#   'user_r6': '0.55255',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2210',
#   'user_name': 'Попов Роман',
#   'user_birthyear': '1985',
#   'user_city': 'Липецк',
#   'user_minraidid': '15',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '4.75242',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '1469',
#   'user_name': 'Сатунин Пётр',
#   'user_birthyear': '1991',
#   'user_city': None,
#   'user_minraidid': '19',
#   'user_maxraidid': '28',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '0.30168',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '3840',
#   'user_name': 'Андреев Алексей',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '29',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '1.09731',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '14092',
#   'user_name': 'Сергей Коперник',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '35',
#   'user_r6': '0.42739',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8857',
#   'user_name': 'Щекочихин Петр Андреевич',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '7',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '0.60818',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14829',
#   'user_name': 'Регинский Станислав',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.19353',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8334',
#   'user_name': 'Борисов Максим',
#   'user_birthyear': '1983',
#   'user_city': 'Тула',
#   'user_minraidid': '24',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.49971',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2088',
#   'user_name': 'Ляшук Юрий',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '23',
#   'user_r6': '2.33514',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1454',
#   'user_name': 'Александр Башкатов',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '19',
#   'user_maxraidid': '35',
#   'user_maxnotstartraidid': '36',
#   'user_r6': '1.30699',
#   'user_noinvitation': '1',
#   'user_sex': '2'},
#  {'user_id': '1784',
#   'user_name': 'Пользователь скрыл данные',
#   'user_birthyear': '1988',
#   'user_city': '',
#   'user_minraidid': '20',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.81364',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2298',
#   'user_name': 'Новосёлов Александр',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '11',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '2.30979',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9597',
#   'user_name': 'Исаев Игорь',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.87548',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9971',
#   'user_name': 'Бушина Екатерина',
#   'user_birthyear': '1997',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.38959',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '1309',
#   'user_name': 'Михеев Артём',
#   'user_birthyear': '1994',
#   'user_city': None,
#   'user_minraidid': '12',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '20',
#   'user_r6': '3.32222',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '718',
#   'user_name': 'Якимов Семён',
#   'user_birthyear': '1991',
#   'user_city': '',
#   'user_minraidid': '16',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '2.71080',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '57',
#   'user_name': 'Френклах Яков',
#   'user_birthyear': '1987',
#   'user_city': None,
#   'user_minraidid': '9',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.31800',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2105',
#   'user_name': 'Галимзянов Тимур',
#   'user_birthyear': '1986',
#   'user_city': 'Москва (ТК МИСиС)',
#   'user_minraidid': '12',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.31161',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '11736',
#   'user_name': 'Хохлов Денис Андреевич',
#   'user_birthyear': '1985',
#   'user_city': 'Москва (ТК МИСиС - ТК Перевал)',
#   'user_minraidid': '29',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.81093',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '3492',
#   'user_name': 'Кудачков Антон',
#   'user_birthyear': '1981',
#   'user_city': None,
#   'user_minraidid': '22',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '23',
#   'user_r6': '1.36425',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12092',
#   'user_name': 'Семенкова Ольга',
#   'user_birthyear': '1982',
#   'user_city': 'Красногорск',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.14968',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '3278',
#   'user_name': 'Носеевич Георгий',
#   'user_birthyear': '1990',
#   'user_city': '',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.48184',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2986',
#   'user_name': 'Вельтищев Михаил',
#   'user_birthyear': '1984',
#   'user_city': 'Москва',
#   'user_minraidid': '10',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '5.55718',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9290',
#   'user_name': 'Ростовский Артём',
#   'user_birthyear': '1991',
#   'user_city': 'Москва',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '26',
#   'user_r6': '2.50903',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10506',
#   'user_name': 'Мишанов Иван',
#   'user_birthyear': '1988',
#   'user_city': 'Москва ТК НИИ ТП',
#   'user_minraidid': '27',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.59554',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1655',
#   'user_name': 'Семиков Александр',
#   'user_birthyear': '1987',
#   'user_city': 'Москва',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.21860',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8500',
#   'user_name': 'Константин Козлов',
#   'user_birthyear': '1991',
#   'user_city': 'Москва',
#   'user_minraidid': '24',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.97533',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10067',
#   'user_name': 'Бабусенко Павел',
#   'user_birthyear': '1990',
#   'user_city': 'Москва',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '34',
#   'user_r6': '1.76957',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '898',
#   'user_name': 'Сериков Денис',
#   'user_birthyear': '1985',
#   'user_city': None,
#   'user_minraidid': '12',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.66600',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1771',
#   'user_name': 'Левандовский Олег',
#   'user_birthyear': '1971',
#   'user_city': 'Краснознаменск',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.05579',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12618',
#   'user_name': 'Мохов Иван',
#   'user_birthyear': '1986',
#   'user_city': 'Еганово',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.34025',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '606',
#   'user_name': 'Лапин Алексей',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '5',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '34',
#   'user_r6': '2.33438',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '9488',
#   'user_name': 'Россинский Александр',
#   'user_birthyear': '1985',
#   'user_city': 'Жуковский',
#   'user_minraidid': '30',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.19126',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '114',
#   'user_name': 'Генкин Сергей',
#   'user_birthyear': '1973',
#   'user_city': 'Москва',
#   'user_minraidid': '5',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '20',
#   'user_r6': '4.56405',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '74',
#   'user_name': 'Сорокин Антон',
#   'user_birthyear': '1969',
#   'user_city': 'Москва',
#   'user_minraidid': '5',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '5.97575',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '2835',
#   'user_name': 'Кузьмишкин Сергей',
#   'user_birthyear': '1952',
#   'user_city': '',
#   'user_minraidid': '21',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '35',
#   'user_r6': '2.49648',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13265',
#   'user_name': 'Солдаткин Антон',
#   'user_birthyear': '1988',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.93942',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '10134',
#   'user_name': 'Баданин Максим',
#   'user_birthyear': '1989',
#   'user_city': 'Долгопрудный',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.54253',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '14819',
#   'user_name': 'Сергей Анатольевич',
#   'user_birthyear': '1985',
#   'user_city': 'Москва',
#   'user_minraidid': '36',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.47229',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '148',
#   'user_name': 'Иванов Василий',
#   'user_birthyear': '1974',
#   'user_city': '',
#   'user_minraidid': '5',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.36616',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8933',
#   'user_name': 'Рубцов Юрий',
#   'user_birthyear': '1973',
#   'user_city': 'Москва',
#   'user_minraidid': '25',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.63980',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '13812',
#   'user_name': 'Будько Светлана',
#   'user_birthyear': '1994',
#   'user_city': 'Минск/Королёв',
#   'user_minraidid': '34',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.00631',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '497',
#   'user_name': 'Молина Ирина',
#   'user_birthyear': '1983',
#   'user_city': '',
#   'user_minraidid': '14',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '3.27997',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '1421',
#   'user_name': 'Жегусов Ярослав',
#   'user_birthyear': '1999',
#   'user_city': '',
#   'user_minraidid': '12',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '6.64115',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1157',
#   'user_name': 'Сапелкин Игорь',
#   'user_birthyear': '1990',
#   'user_city': None,
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '5.60402',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '882',
#   'user_name': 'Рощин Роман',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '5',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '20',
#   'user_r6': '5.32116',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '883',
#   'user_name': 'Колесов Сергей',
#   'user_birthyear': '1979',
#   'user_city': '',
#   'user_minraidid': '7',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '20',
#   'user_r6': '5.85318',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '4131',
#   'user_name': 'Бочагин Михаил',
#   'user_birthyear': '1982',
#   'user_city': 'Москва',
#   'user_minraidid': '23',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': '25',
#   'user_r6': '5.08613',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '8447',
#   'user_name': 'Семенов Сергей',
#   'user_birthyear': '1982',
#   'user_city': 'Пушкино',
#   'user_minraidid': '26',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '4.04123',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '726',
#   'user_name': 'Никитин Андрей',
#   'user_birthyear': '1986',
#   'user_city': '',
#   'user_minraidid': '18',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.82895',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12680',
#   'user_name': 'Олег Нагайченко',
#   'user_birthyear': '1972',
#   'user_city': 'Тамбов',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '2.39198',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '12596',
#   'user_name': 'Капарулин Ефим',
#   'user_birthyear': '1975',
#   'user_city': 'Королев',
#   'user_minraidid': '31',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.91063',
#   'user_noinvitation': None,
#   'user_sex': '2'},
#  {'user_id': '1073',
#   'user_name': 'Евстигнеева Елизавета',
#   'user_birthyear': '1976',
#   'user_city': 'Королев',
#   'user_minraidid': '19',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '0.67840',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13126',
#   'user_name': 'Некрасова Екатерина Сергеевна',
#   'user_birthyear': '1980',
#   'user_city': 'Москва',
#   'user_minraidid': '32',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.78394',
#   'user_noinvitation': None,
#   'user_sex': '1'},
#  {'user_id': '13378',
#   'user_name': 'Достовалов Артур',
#   'user_birthyear': '1983',
#   'user_city': 'Москва',
#   'user_minraidid': '33',
#   'user_maxraidid': '36',
#   'user_maxnotstartraidid': None,
#   'user_r6': '1.56464',
#   'user_noinvitation': None,
#   'user_sex': '2'}]

# %%
import json
data2 = json.load(open('public/TeamLevelPoints.json'))

# %%
list(filter(( lambda x: x['team_id'] == '38829'),data2['TeamLevelPoints']))
# Out:
# [{'teamlevelpoint_id': '1510433',
#   'team_id': '38829',
#   'levelpoint_id': '2150',
#   'teamlevelpoint_datetime': '2021-10-29 18:22:15',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': None,
#   'teamlevelpoint_durationdecimal': '0.0000000000',
#   'teamlevelpoint_result': '00:00:00'},
#  {'teamlevelpoint_id': '1510434',
#   'team_id': '38829',
#   'levelpoint_id': '2151',
#   'teamlevelpoint_datetime': '2021-10-29 19:25:35',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:03:20',
#   'teamlevelpoint_durationdecimal': '63.3333333330',
#   'teamlevelpoint_result': '01:03:20'},
#  {'teamlevelpoint_id': '1510435',
#   'team_id': '38829',
#   'levelpoint_id': '2152',
#   'teamlevelpoint_datetime': '2021-10-29 20:31:54',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:06:19',
#   'teamlevelpoint_durationdecimal': '66.3166666660',
#   'teamlevelpoint_result': '02:09:39'},
#  {'teamlevelpoint_id': '1510436',
#   'team_id': '38829',
#   'levelpoint_id': '2153',
#   'teamlevelpoint_datetime': '2021-10-29 21:13:34',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:41:40',
#   'teamlevelpoint_durationdecimal': '41.6666666660',
#   'teamlevelpoint_result': '02:51:19'},
#  {'teamlevelpoint_id': '1510437',
#   'team_id': '38829',
#   'levelpoint_id': '2154',
#   'teamlevelpoint_datetime': '2021-10-29 21:30:26',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:16:52',
#   'teamlevelpoint_durationdecimal': '16.8666666660',
#   'teamlevelpoint_result': '03:08:11'},
#  {'teamlevelpoint_id': '1510438',
#   'team_id': '38829',
#   'levelpoint_id': '2155',
#   'teamlevelpoint_datetime': '2021-10-29 22:14:04',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:43:38',
#   'teamlevelpoint_durationdecimal': '43.6333333330',
#   'teamlevelpoint_result': '03:51:49'},
#  {'teamlevelpoint_id': '1510439',
#   'team_id': '38829',
#   'levelpoint_id': '2157',
#   'teamlevelpoint_datetime': '2021-10-29 22:52:00',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '60',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:37:56',
#   'teamlevelpoint_durationdecimal': '37.9333333330',
#   'teamlevelpoint_result': '05:29:45'},
#  {'teamlevelpoint_id': '1510440',
#   'team_id': '38829',
#   'levelpoint_id': '2158',
#   'teamlevelpoint_datetime': '2021-10-29 23:20:31',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:28:31',
#   'teamlevelpoint_durationdecimal': '28.5166666660',
#   'teamlevelpoint_result': '05:58:16'},
#  {'teamlevelpoint_id': '1510441',
#   'team_id': '38829',
#   'levelpoint_id': '2161',
#   'teamlevelpoint_datetime': '2021-10-30 00:16:57',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '120',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:56:26',
#   'teamlevelpoint_durationdecimal': '56.4333333330',
#   'teamlevelpoint_result': '08:54:42'},
#  {'teamlevelpoint_id': '1510442',
#   'team_id': '38829',
#   'levelpoint_id': '2163',
#   'teamlevelpoint_datetime': '2021-10-30 00:48:04',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '60',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:31:07',
#   'teamlevelpoint_durationdecimal': '31.1166666660',
#   'teamlevelpoint_result': '10:25:49'},
#  {'teamlevelpoint_id': '1510443',
#   'team_id': '38829',
#   'levelpoint_id': '2170',
#   'teamlevelpoint_datetime': '2021-10-30 01:35:14',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '360',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:47:10',
#   'teamlevelpoint_durationdecimal': '47.1666666660',
#   'teamlevelpoint_result': '17:12:59'},
#  {'teamlevelpoint_id': '1510444',
#   'team_id': '38829',
#   'levelpoint_id': '2172',
#   'teamlevelpoint_datetime': '2021-10-30 02:21:14',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '60',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:46:00',
#   'teamlevelpoint_durationdecimal': '46.0000000000',
#   'teamlevelpoint_result': '18:58:59'},
#  {'teamlevelpoint_id': '1510445',
#   'team_id': '38829',
#   'levelpoint_id': '2173',
#   'teamlevelpoint_datetime': '2021-10-30 11:52:15',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '09:31:01',
#   'teamlevelpoint_durationdecimal': '571.0166666660',
#   'teamlevelpoint_result': '28:30:00'},
#  {'teamlevelpoint_id': '1510446',
#   'team_id': '38829',
#   'levelpoint_id': '2174',
#   'teamlevelpoint_datetime': '2021-10-30 12:52:08',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:59:53',
#   'teamlevelpoint_durationdecimal': '59.8833333330',
#   'teamlevelpoint_result': '29:29:53'},
#  {'teamlevelpoint_id': '1510447',
#   'team_id': '38829',
#   'levelpoint_id': '2175',
#   'teamlevelpoint_datetime': '2021-10-30 14:10:18',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:18:10',
#   'teamlevelpoint_durationdecimal': '78.1666666660',
#   'teamlevelpoint_result': '30:48:03'},
#  {'teamlevelpoint_id': '1510448',
#   'team_id': '38829',
#   'levelpoint_id': '2178',
#   'teamlevelpoint_datetime': '2021-10-30 14:53:46',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '240',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:43:28',
#   'teamlevelpoint_durationdecimal': '43.4666666660',
#   'teamlevelpoint_result': '35:31:31'},
#  {'teamlevelpoint_id': '1510449',
#   'team_id': '38829',
#   'levelpoint_id': '2185',
#   'teamlevelpoint_datetime': '2021-10-31 09:24:51',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '246',
#   'error_id': '0',
#   'teamlevelpoint_duration': None,
#   'teamlevelpoint_durationdecimal': '0.0000000000',
#   'teamlevelpoint_result': '52:01:43'},
#  {'teamlevelpoint_id': '1510450',
#   'team_id': '38829',
#   'levelpoint_id': '2186',
#   'teamlevelpoint_datetime': '2021-10-31 10:40:00',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:15:09',
#   'teamlevelpoint_durationdecimal': '75.1500000000',
#   'teamlevelpoint_result': '53:16:52'},
#  {'teamlevelpoint_id': '1510451',
#   'team_id': '38829',
#   'levelpoint_id': '2187',
#   'teamlevelpoint_datetime': '2021-10-31 11:27:25',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:47:25',
#   'teamlevelpoint_durationdecimal': '47.4166666660',
#   'teamlevelpoint_result': '54:04:17'},
#  {'teamlevelpoint_id': '1510452',
#   'team_id': '38829',
#   'levelpoint_id': '2188',
#   'teamlevelpoint_datetime': '2021-10-31 13:21:21',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:53:56',
#   'teamlevelpoint_durationdecimal': '113.9333333330',
#   'teamlevelpoint_result': '55:58:13'},
#  {'teamlevelpoint_id': '1510453',
#   'team_id': '38829',
#   'levelpoint_id': '2189',
#   'teamlevelpoint_datetime': '2021-10-31 13:43:47',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:22:26',
#   'teamlevelpoint_durationdecimal': '22.4333333330',
#   'teamlevelpoint_result': '56:20:39'},
#  {'teamlevelpoint_id': '1510454',
#   'team_id': '38829',
#   'levelpoint_id': '2190',
#   'teamlevelpoint_datetime': '2021-10-31 14:34:20',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:50:33',
#   'teamlevelpoint_durationdecimal': '50.5500000000',
#   'teamlevelpoint_result': '57:11:12'},
#  {'teamlevelpoint_id': '1510455',
#   'team_id': '38829',
#   'levelpoint_id': '2191',
#   'teamlevelpoint_datetime': '2021-10-31 15:27:31',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:53:11',
#   'teamlevelpoint_durationdecimal': '53.1833333330',
#   'teamlevelpoint_result': '58:04:23'},
#  {'teamlevelpoint_id': '1510456',
#   'team_id': '38829',
#   'levelpoint_id': '2192',
#   'teamlevelpoint_datetime': '2021-10-31 16:51:22',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:23:51',
#   'teamlevelpoint_durationdecimal': '83.8500000000',
#   'teamlevelpoint_result': '59:28:14'},
#  {'teamlevelpoint_id': '1510457',
#   'team_id': '38829',
#   'levelpoint_id': '2193',
#   'teamlevelpoint_datetime': '2021-10-31 17:09:18',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:17:56',
#   'teamlevelpoint_durationdecimal': '17.9333333330',
#   'teamlevelpoint_result': '59:46:10'},
#  {'teamlevelpoint_id': '1510458',
#   'team_id': '38829',
#   'levelpoint_id': '2199',
#   'teamlevelpoint_datetime': '2021-10-31 17:46:27',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '300',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:37:09',
#   'teamlevelpoint_durationdecimal': '37.1500000000',
#   'teamlevelpoint_result': '65:23:19'},
#  {'teamlevelpoint_id': '1510459',
#   'team_id': '38829',
#   'levelpoint_id': '2203',
#   'teamlevelpoint_datetime': '2021-10-31 18:14:01',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '180',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:27:34',
#   'teamlevelpoint_durationdecimal': '27.5666666660',
#   'teamlevelpoint_result': '68:50:53'},
#  {'teamlevelpoint_id': '1511032',
#   'team_id': '38829',
#   'levelpoint_id': '2184',
#   'teamlevelpoint_datetime': '2021-10-30 17:17:58',
#   'teamlevelpoint_comment': '',
#   'teamlevelpoint_penalty': '600',
#   'error_id': '0',
#   'teamlevelpoint_duration': '02:24:12',
#   'teamlevelpoint_durationdecimal': '144.2000000000',
#   'teamlevelpoint_result': '47:55:43'}]

# %%
list(filter(lambda x: x['team_id']=='38523', data2['TeamLevelPoints']))
# Out:
# [{'teamlevelpoint_id': '1491330',
#   'team_id': '38523',
#   'levelpoint_id': '2150',
#   'teamlevelpoint_datetime': '2021-10-29 16:48:06',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': None,
#   'teamlevelpoint_durationdecimal': '0.0000000000',
#   'teamlevelpoint_result': '00:00:00'},
#  {'teamlevelpoint_id': '1491331',
#   'team_id': '38523',
#   'levelpoint_id': '2151',
#   'teamlevelpoint_datetime': '2021-10-29 17:22:55',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:34:49',
#   'teamlevelpoint_durationdecimal': '34.8166666660',
#   'teamlevelpoint_result': '00:34:49'},
#  {'teamlevelpoint_id': '1491332',
#   'team_id': '38523',
#   'levelpoint_id': '2152',
#   'teamlevelpoint_datetime': '2021-10-29 18:02:07',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:39:12',
#   'teamlevelpoint_durationdecimal': '39.2000000000',
#   'teamlevelpoint_result': '01:14:01'},
#  {'teamlevelpoint_id': '1491333',
#   'team_id': '38523',
#   'levelpoint_id': '2153',
#   'teamlevelpoint_datetime': '2021-10-29 18:20:16',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:18:09',
#   'teamlevelpoint_durationdecimal': '18.1500000000',
#   'teamlevelpoint_result': '01:32:10'},
#  {'teamlevelpoint_id': '1491334',
#   'team_id': '38523',
#   'levelpoint_id': '2154',
#   'teamlevelpoint_datetime': '2021-10-29 18:33:10',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:12:54',
#   'teamlevelpoint_durationdecimal': '12.9000000000',
#   'teamlevelpoint_result': '01:45:04'},
#  {'teamlevelpoint_id': '1491335',
#   'team_id': '38523',
#   'levelpoint_id': '2155',
#   'teamlevelpoint_datetime': '2021-10-29 18:58:05',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:24:55',
#   'teamlevelpoint_durationdecimal': '24.9166666660',
#   'teamlevelpoint_result': '02:09:59'},
#  {'teamlevelpoint_id': '1491336',
#   'team_id': '38523',
#   'levelpoint_id': '2156',
#   'teamlevelpoint_datetime': '2021-10-29 19:19:56',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:21:51',
#   'teamlevelpoint_durationdecimal': '21.8500000000',
#   'teamlevelpoint_result': '02:31:50'},
#  {'teamlevelpoint_id': '1491337',
#   'team_id': '38523',
#   'levelpoint_id': '2158',
#   'teamlevelpoint_datetime': '2021-10-29 19:37:43',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:17:47',
#   'teamlevelpoint_durationdecimal': '17.7833333330',
#   'teamlevelpoint_result': '02:49:37'},
#  {'teamlevelpoint_id': '1491338',
#   'team_id': '38523',
#   'levelpoint_id': '2157',
#   'teamlevelpoint_datetime': '2021-10-29 19:55:44',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:18:01',
#   'teamlevelpoint_durationdecimal': '18.0166666660',
#   'teamlevelpoint_result': '03:07:38'},
#  {'teamlevelpoint_id': '1491339',
#   'team_id': '38523',
#   'levelpoint_id': '2160',
#   'teamlevelpoint_datetime': '2021-10-29 20:15:25',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:19:41',
#   'teamlevelpoint_durationdecimal': '19.6833333330',
#   'teamlevelpoint_result': '03:27:19'},
#  {'teamlevelpoint_id': '1491340',
#   'team_id': '38523',
#   'levelpoint_id': '2161',
#   'teamlevelpoint_datetime': '2021-10-29 20:50:36',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:35:11',
#   'teamlevelpoint_durationdecimal': '35.1833333330',
#   'teamlevelpoint_result': '04:02:30'},
#  {'teamlevelpoint_id': '1491341',
#   'team_id': '38523',
#   'levelpoint_id': '2159',
#   'teamlevelpoint_datetime': '2021-10-29 21:11:11',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:20:35',
#   'teamlevelpoint_durationdecimal': '20.5833333330',
#   'teamlevelpoint_result': '04:23:05'},
#  {'teamlevelpoint_id': '1491342',
#   'team_id': '38523',
#   'levelpoint_id': '2162',
#   'teamlevelpoint_datetime': '2021-10-29 21:44:05',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:32:54',
#   'teamlevelpoint_durationdecimal': '32.9000000000',
#   'teamlevelpoint_result': '04:55:59'},
#  {'teamlevelpoint_id': '1491343',
#   'team_id': '38523',
#   'levelpoint_id': '2163',
#   'teamlevelpoint_datetime': '2021-10-29 22:21:20',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:37:15',
#   'teamlevelpoint_durationdecimal': '37.2500000000',
#   'teamlevelpoint_result': '05:33:14'},
#  {'teamlevelpoint_id': '1491344',
#   'team_id': '38523',
#   'levelpoint_id': '2164',
#   'teamlevelpoint_datetime': '2021-10-29 23:09:32',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:48:12',
#   'teamlevelpoint_durationdecimal': '48.2000000000',
#   'teamlevelpoint_result': '06:21:26'},
#  {'teamlevelpoint_id': '1491345',
#   'team_id': '38523',
#   'levelpoint_id': '2167',
#   'teamlevelpoint_datetime': '2021-10-29 23:32:43',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:23:11',
#   'teamlevelpoint_durationdecimal': '23.1833333330',
#   'teamlevelpoint_result': '06:44:37'},
#  {'teamlevelpoint_id': '1491346',
#   'team_id': '38523',
#   'levelpoint_id': '2165',
#   'teamlevelpoint_datetime': '2021-10-29 23:58:10',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:25:27',
#   'teamlevelpoint_durationdecimal': '25.4500000000',
#   'teamlevelpoint_result': '07:10:04'},
#  {'teamlevelpoint_id': '1491347',
#   'team_id': '38523',
#   'levelpoint_id': '2166',
#   'teamlevelpoint_datetime': '2021-10-30 00:19:09',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:20:59',
#   'teamlevelpoint_durationdecimal': '20.9833333330',
#   'teamlevelpoint_result': '07:31:03'},
#  {'teamlevelpoint_id': '1491348',
#   'team_id': '38523',
#   'levelpoint_id': '2169',
#   'teamlevelpoint_datetime': '2021-10-30 01:00:07',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:40:58',
#   'teamlevelpoint_durationdecimal': '40.9666666660',
#   'teamlevelpoint_result': '08:12:01'},
#  {'teamlevelpoint_id': '1491349',
#   'team_id': '38523',
#   'levelpoint_id': '2171',
#   'teamlevelpoint_datetime': '2021-10-30 01:31:03',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:30:56',
#   'teamlevelpoint_durationdecimal': '30.9333333330',
#   'teamlevelpoint_result': '08:42:57'},
#  {'teamlevelpoint_id': '1491350',
#   'team_id': '38523',
#   'levelpoint_id': '2168',
#   'teamlevelpoint_datetime': '2021-10-30 01:48:55',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:17:52',
#   'teamlevelpoint_durationdecimal': '17.8666666660',
#   'teamlevelpoint_result': '09:00:49'},
#  {'teamlevelpoint_id': '1491351',
#   'team_id': '38523',
#   'levelpoint_id': '2170',
#   'teamlevelpoint_datetime': '2021-10-30 02:12:35',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:23:40',
#   'teamlevelpoint_durationdecimal': '23.6666666660',
#   'teamlevelpoint_result': '09:24:29'},
#  {'teamlevelpoint_id': '1491352',
#   'team_id': '38523',
#   'levelpoint_id': '2172',
#   'teamlevelpoint_datetime': '2021-10-30 02:34:52',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:22:17',
#   'teamlevelpoint_durationdecimal': '22.2833333330',
#   'teamlevelpoint_result': '09:46:46'},
#  {'teamlevelpoint_id': '1491353',
#   'team_id': '38523',
#   'levelpoint_id': '2173',
#   'teamlevelpoint_datetime': '2021-10-30 03:40:40',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:05:48',
#   'teamlevelpoint_durationdecimal': '65.8000000000',
#   'teamlevelpoint_result': '10:52:34'},
#  {'teamlevelpoint_id': '1491354',
#   'team_id': '38523',
#   'levelpoint_id': '2174',
#   'teamlevelpoint_datetime': '2021-10-30 04:45:01',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:04:21',
#   'teamlevelpoint_durationdecimal': '64.3500000000',
#   'teamlevelpoint_result': '11:56:55'},
#  {'teamlevelpoint_id': '1491355',
#   'team_id': '38523',
#   'levelpoint_id': '2175',
#   'teamlevelpoint_datetime': '2021-10-30 06:04:17',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:19:16',
#   'teamlevelpoint_durationdecimal': '79.2666666660',
#   'teamlevelpoint_result': '13:16:11'},
#  {'teamlevelpoint_id': '1491356',
#   'team_id': '38523',
#   'levelpoint_id': '2178',
#   'teamlevelpoint_datetime': '2021-10-30 06:52:19',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:48:02',
#   'teamlevelpoint_durationdecimal': '48.0333333330',
#   'teamlevelpoint_result': '14:04:13'},
#  {'teamlevelpoint_id': '1491357',
#   'team_id': '38523',
#   'levelpoint_id': '2179',
#   'teamlevelpoint_datetime': '2021-10-30 08:12:47',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:20:28',
#   'teamlevelpoint_durationdecimal': '80.4666666660',
#   'teamlevelpoint_result': '15:24:41'},
#  {'teamlevelpoint_id': '1491358',
#   'team_id': '38523',
#   'levelpoint_id': '2177',
#   'teamlevelpoint_datetime': '2021-10-30 09:05:50',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': '120',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:53:03',
#   'teamlevelpoint_durationdecimal': '53.0500000000',
#   'teamlevelpoint_result': '18:17:44'},
#  {'teamlevelpoint_id': '1491359',
#   'team_id': '38523',
#   'levelpoint_id': '2180',
#   'teamlevelpoint_datetime': '2021-10-30 09:45:24',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:39:34',
#   'teamlevelpoint_durationdecimal': '39.5666666660',
#   'teamlevelpoint_result': '18:57:18'},
#  {'teamlevelpoint_id': '1491360',
#   'team_id': '38523',
#   'levelpoint_id': '2182',
#   'teamlevelpoint_datetime': '2021-10-30 10:27:30',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': '120',
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:42:06',
#   'teamlevelpoint_durationdecimal': '42.1000000000',
#   'teamlevelpoint_result': '21:39:24'},
#  {'teamlevelpoint_id': '1491361',
#   'team_id': '38523',
#   'levelpoint_id': '2183',
#   'teamlevelpoint_datetime': '2021-10-30 11:04:08',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:36:38',
#   'teamlevelpoint_durationdecimal': '36.6333333330',
#   'teamlevelpoint_result': '22:16:02'},
#  {'teamlevelpoint_id': '1491362',
#   'team_id': '38523',
#   'levelpoint_id': '2184',
#   'teamlevelpoint_datetime': '2021-10-30 12:35:40',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:31:32',
#   'teamlevelpoint_durationdecimal': '91.5333333330',
#   'teamlevelpoint_result': '23:47:34'},
#  {'teamlevelpoint_id': '1491363',
#   'team_id': '38523',
#   'levelpoint_id': '2185',
#   'teamlevelpoint_datetime': '2021-10-31 08:18:35',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': '462',
#   'error_id': '0',
#   'teamlevelpoint_duration': None,
#   'teamlevelpoint_durationdecimal': '0.0000000000',
#   'teamlevelpoint_result': '31:29:34'},
#  {'teamlevelpoint_id': '1491364',
#   'team_id': '38523',
#   'levelpoint_id': '2186',
#   'teamlevelpoint_datetime': '2021-10-31 09:17:13',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:58:38',
#   'teamlevelpoint_durationdecimal': '58.6333333330',
#   'teamlevelpoint_result': '32:28:12'},
#  {'teamlevelpoint_id': '1491365',
#   'team_id': '38523',
#   'levelpoint_id': '2187',
#   'teamlevelpoint_datetime': '2021-10-31 09:54:55',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:37:42',
#   'teamlevelpoint_durationdecimal': '37.7000000000',
#   'teamlevelpoint_result': '33:05:54'},
#  {'teamlevelpoint_id': '1491366',
#   'team_id': '38523',
#   'levelpoint_id': '2188',
#   'teamlevelpoint_datetime': '2021-10-31 11:22:10',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:27:15',
#   'teamlevelpoint_durationdecimal': '87.2500000000',
#   'teamlevelpoint_result': '34:33:09'},
#  {'teamlevelpoint_id': '1491367',
#   'team_id': '38523',
#   'levelpoint_id': '2189',
#   'teamlevelpoint_datetime': '2021-10-31 11:45:19',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:23:09',
#   'teamlevelpoint_durationdecimal': '23.1500000000',
#   'teamlevelpoint_result': '34:56:18'},
#  {'teamlevelpoint_id': '1491368',
#   'team_id': '38523',
#   'levelpoint_id': '2190',
#   'teamlevelpoint_datetime': '2021-10-31 12:35:29',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:50:10',
#   'teamlevelpoint_durationdecimal': '50.1666666660',
#   'teamlevelpoint_result': '35:46:28'},
#  {'teamlevelpoint_id': '1491369',
#   'team_id': '38523',
#   'levelpoint_id': '2191',
#   'teamlevelpoint_datetime': '2021-10-31 14:04:22',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:28:53',
#   'teamlevelpoint_durationdecimal': '88.8833333330',
#   'teamlevelpoint_result': '37:15:21'},
#  {'teamlevelpoint_id': '1491370',
#   'team_id': '38523',
#   'levelpoint_id': '2192',
#   'teamlevelpoint_datetime': '2021-10-31 15:10:48',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '01:06:26',
#   'teamlevelpoint_durationdecimal': '66.4333333330',
#   'teamlevelpoint_result': '38:21:47'},
#  {'teamlevelpoint_id': '1491371',
#   'team_id': '38523',
#   'levelpoint_id': '2193',
#   'teamlevelpoint_datetime': '2021-10-31 15:53:49',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:43:01',
#   'teamlevelpoint_durationdecimal': '43.0166666660',
#   'teamlevelpoint_result': '39:04:48'},
#  {'teamlevelpoint_id': '1491372',
#   'team_id': '38523',
#   'levelpoint_id': '2198',
#   'teamlevelpoint_datetime': '2021-10-31 16:12:55',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:19:06',
#   'teamlevelpoint_durationdecimal': '19.1000000000',
#   'teamlevelpoint_result': '39:23:54'},
#  {'teamlevelpoint_id': '1491373',
#   'team_id': '38523',
#   'levelpoint_id': '2194',
#   'teamlevelpoint_datetime': '2021-10-31 16:23:45',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:10:50',
#   'teamlevelpoint_durationdecimal': '10.8333333330',
#   'teamlevelpoint_result': '39:34:44'},
#  {'teamlevelpoint_id': '1491374',
#   'team_id': '38523',
#   'levelpoint_id': '2195',
#   'teamlevelpoint_datetime': '2021-10-31 16:43:50',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:20:05',
#   'teamlevelpoint_durationdecimal': '20.0833333330',
#   'teamlevelpoint_result': '39:54:49'},
#  {'teamlevelpoint_id': '1491375',
#   'team_id': '38523',
#   'levelpoint_id': '2196',
#   'teamlevelpoint_datetime': '2021-10-31 16:57:45',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:13:55',
#   'teamlevelpoint_durationdecimal': '13.9166666660',
#   'teamlevelpoint_result': '40:08:44'},
#  {'teamlevelpoint_id': '1491376',
#   'team_id': '38523',
#   'levelpoint_id': '2200',
#   'teamlevelpoint_datetime': '2021-10-31 17:09:37',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:11:52',
#   'teamlevelpoint_durationdecimal': '11.8666666660',
#   'teamlevelpoint_result': '40:20:36'},
#  {'teamlevelpoint_id': '1491377',
#   'team_id': '38523',
#   'levelpoint_id': '2199',
#   'teamlevelpoint_datetime': '2021-10-31 17:19:13',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:09:36',
#   'teamlevelpoint_durationdecimal': '9.6000000000',
#   'teamlevelpoint_result': '40:30:12'},
#  {'teamlevelpoint_id': '1491378',
#   'team_id': '38523',
#   'levelpoint_id': '2197',
#   'teamlevelpoint_datetime': '2021-10-31 17:41:06',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:21:53',
#   'teamlevelpoint_durationdecimal': '21.8833333330',
#   'teamlevelpoint_result': '40:52:05'},
#  {'teamlevelpoint_id': '1491379',
#   'team_id': '38523',
#   'levelpoint_id': '2201',
#   'teamlevelpoint_datetime': '2021-10-31 17:56:23',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:15:17',
#   'teamlevelpoint_durationdecimal': '15.2833333330',
#   'teamlevelpoint_result': '41:07:22'},
#  {'teamlevelpoint_id': '1491380',
#   'team_id': '38523',
#   'levelpoint_id': '2202',
#   'teamlevelpoint_datetime': '2021-10-31 18:11:22',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:14:59',
#   'teamlevelpoint_durationdecimal': '14.9833333330',
#   'teamlevelpoint_result': '41:22:21'},
#  {'teamlevelpoint_id': '1491381',
#   'team_id': '38523',
#   'levelpoint_id': '2203',
#   'teamlevelpoint_datetime': '2021-10-31 18:30:17',
#   'teamlevelpoint_comment': None,
#   'teamlevelpoint_penalty': None,
#   'error_id': '0',
#   'teamlevelpoint_duration': '00:18:55',
#   'teamlevelpoint_durationdecimal': '18.9166666660',
#   'teamlevelpoint_result': '41:41:16'}]

# %% [markdown]
# ### Что нужно добыть из данных на первом этапе
#
# - К команде нужно прикрутить список их КПшек, расположенных в порядке взятия. У каждой КП должен быть результат текущий, чтобы легко можно было посчитать отставание.
# - Нужно опряделять место на перегоне. Для этого нам нужны перегоны основной команды в текущей конфигурации таблицы(перегоны Старт-СК например), поэтому делаем не сразу. Тут нужен какой-то кеш наверно, так как возможно это будет считаться долго, хотя надо проверить.
